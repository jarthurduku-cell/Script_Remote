# %%
## Practice before actual assignment.

from bs4 import BeautifulSoup
import requests, re

url = "http://en.wikipedia.org/wiki/JavaScript"
headers = {'User-Agent' : 'Anthony'}
response = requests.get(url, headers=headers)
print(response.status_code)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

print(soup.title) #prints with the tags
print(soup.title.get_text()) # prints without the tags


print(soup.get_text().lower().count("object"))

h2_tag = soup.find("h2")  #.find("h2") finds only the first h2 tag.
print(h2_tag)

h2_tags = soup.find_all("h2")
print(len(h2_tags))

for tag in h2_tags:
    print(tag.get_text())

# %%
from bs4 import BeautifulSoup
import requests, re

url = "https://killer.cloud/"
headers = {'User-Agent' : 'Anthony'}
response = requests.get(url, headers=headers)
print(response.status_code)
html = response.text    
print(response.content)
soup = BeautifulSoup(html, 'html.parser')

print(soup.title)

# %%
from bs4 import BeautifulSoup
import requests, re

#https://killer.cloud/serial-killers/by/country/belgium
#https://killer.cloud/serial-killers/by/years-active

location = input("Enter your location (I mean country):")
n = int(input("Enter the number of top killers you want to see:"))
sort_by = input("Enter the sorting criteria (confirmed-kills, years-active):")
def top_killers(n, sort_by , location):
    
    if location != "world":
        url = f"https://killer.cloud/serial-killers/by/country/{location}?page=1"
        headers = {'User-Agent' : 'Anthony'}
        response = requests.get(url, headers=headers)
        print(response.status_code)
        #html = response.text    
        soup = BeautifulSoup(response.content, 'html.parser') 
        print(soup.title)  
        
    
        #pad10t mar5t font-hel text-left w 
        naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
        victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
        act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
        links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})
        
        finalList = []
        print("---------------------------------------------------------------------------------------")
        for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
            diction = {
            'name' : naamen[i].get_text(),
            'victim': victims[i].get_text(),
            'years' : act_years[i].get_text(),
            'url' :  links[i]['href']
            }    
            finalList.append(diction)
            
        p = 2    
        while len(finalList) < n:
            url =  f"https://killer.cloud/serial-killers/by/country/{location}?page={p}"
            p += 1
            headers = {'User-Agent' : 'Anthony'}
            response = requests.get(url, headers=headers)
            #print(response.status_code)
            #html = response.text    
            soup = BeautifulSoup(response.content, 'html.parser')

            naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
            victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
            act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
            links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})

            if not naamen:
                break
            for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
                diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
                finalList.append(diction)
   
        if n < len(finalList):
            print(finalList[:n])
            print(len(finalList[:n]))
        else:
            print(finalList)
            print(len(finalList))
        print("----------------------------------------------------------------------------------------")   
        i = 1
        for x in finalList[:n]:
            print(i, x["name"])
            i += 1
            
        
            
        print("\n--------------------------------------------------------------------------------------")
    
    elif location == "world" and sort_by == "years-active":   
        
        url = f"https://killer.cloud/serial-killers/by/years-active?page=1"
        headers = {'User-Agent' : 'Anthony'}
        response = requests.get(url, headers=headers)
        #print(response.status_code)
        #html = response.text    
        soup = BeautifulSoup(response.content, 'html.parser')

        naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
        victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
        act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
        links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})

        finale = []
        for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
            diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
            finale.append(diction)
        p = 2
        #print(finale, "just the list")
        
            
        while len(finale) < n:
            url = f"https://killer.cloud/serial-killers/by/years-active?page={p}"
            p += 1
            headers = {'User-Agent' : 'Anthony'}
            response = requests.get(url, headers=headers)
            #print(response.status_code)
            #html = response.text    
            soup = BeautifulSoup(response.content, 'html.parser')

            naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
            victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
            act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
            links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})

            for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
                diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
                finale.append(diction)
   
        if n < len(finale):
            print(finale[:n], "everything up to n can be less than the whole list")
            print(len(finale[:n]))
        else:
            print(finale)
            
    elif location == "world" and sort_by == "confirmed-kills":  
        
        url = f"https://killer.cloud/serial-killers/by/confirmed-kills?page=1"
        headers = {'User-Agent' : 'Anthony'}
        response = requests.get(url, headers=headers)
        #print(response.status_code)
        #html = response.text    
        soup = BeautifulSoup(response.content, 'html.parser')

        naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
        victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
        act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
        links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})

        finale = []
        for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
            diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
            finale.append(diction)
        p = 2
        #print(finale, "just the list")
        
            
        while len(finale) < n:
            url = f"https://killer.cloud/serial-killers/by/confirmed-kills?page={p}"
            p += 1
            headers = {'User-Agent' : 'Anthony'}
            response = requests.get(url, headers=headers)
            #print(response.status_code)
            #html = response.text    
            soup = BeautifulSoup(response.content, 'html.parser')

            naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
            victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
            act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
            links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})

            for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
                diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
                finale.append(diction)
   
        if n < len(finale):
            print(finale[:n], "everything up to n can be less than the whole list")
            print(len(finale[:n]))
        else:
            print(finale)
            
            
top_killers(n, sort_by, location)
# Out:
# 200
# <title>List of 2 serial killers active in Belgium - Killer.Cloud</title>
# ---------------------------------------------------------------------------------------
# [{'name': ' András Pándy  Father Bluebeard, The Family Killer ', 'victim': '6', 'years': ' 5 ', 'url': 'https://killer.cloud/serial-killers/show/240/andras-pandy'}, {'name': ' Marc Dutroux  Dutroux murders ', 'victim': '5', 'years': ' 1 ', 'url': 'https://killer.cloud/serial-killers/show/278/marc-dutroux'}]
# 2
# ----------------------------------------------------------------------------------------
# 1  András Pándy  Father Bluebeard, The Family Killer
# 2  Marc Dutroux  Dutroux murders
#
# --------------------------------------------------------------------------------------
# {'name': ' John Floyd Thomas  Westside Rapist, The Southland Strangler ', 'victims': 5, 'years': 53, 'url': 'https://killer.cloud/serial-killers/show/255/john-floyd-thomas'}
# {'name': ' David Parker Ray  The Toy-Box Killer ', 'victims': 3, 'years': 43, 'url': 'https://killer.cloud/serial-killers/show/663/david-parker-ray'}
# {'name': ' Richard Kuklinski  The Iceman, The Polack ', 'victims': 6, 'years': 38, 'url': 'https://killer.cloud/serial-killers/show/659/richard-kuklinski'}
# {'name': ' Pedro Rodrigues Filho  Pedrinho Matador, Killer Petey ', 'victims': 71, 'years': 37, 'url': 'https://killer.cloud/serial-killers/show/3/pedro-rodrigues-filho'}
# {'name': ' Samuel Little  Samuel McDowell ', 'victims': 60, 'years': 36, 'url': 'https://killer.cloud/serial-killers/show/597/sam-little'}
# {'name': ' Peter Woodcock  David Michael Krueger ', 'victims': 4, 'years': 36, 'url': 'https://killer.cloud/serial-killers/show/325/peter-woodcock'}
# {'name': ' Pedro Lopez  The Monster of the Andes ', 'victims': 110, 'years': 34, 'url': 'https://killer.cloud/serial-killers/show/1/pedro-lopez'}
# {'name': ' Volker Eckert  Brummi Killer ', 'victims': 9, 'years': 33, 'url': 'https://killer.cloud/serial-killers/show/141/volker-eckert'}
# {'name': ' Carroll Edward Cole  Carroll Cole ', 'victims': 16, 'years': 33, 'url': 'https://killer.cloud/serial-killers/show/60/carroll-cole'}
# {'name': ' Louise Peete  Lofie Louise Preslar ', 'victims': 3, 'years': 31, 'url': 'https://killer.cloud/serial-killers/show/385/louise-peete'}
# {'name': ' Willem van Eijk  The Beast of Harkstede, Gekke Willempje ', 'victims': 5, 'years': 31, 'url': 'https://killer.cloud/serial-killers/show/299/willem-van-eijk'}
# {'name': ' Dennis Rader  BTK Killer, BTK Strangler, Bind Torture Kill ', 'victims': 10, 'years': 31, 'url': 'https://killer.cloud/serial-killers/show/130/dennis-rader'}
# {'name': ' David Edward Maust  Crazy Dave ', 'victims': 5, 'years': 30, 'url': 'https://killer.cloud/serial-killers/show/261/david-maust'}
# {'name': ' Donald Henry Gaskins  Pee Wee, The Meanest Man in America ', 'victims': 12, 'years': 30, 'url': 'https://killer.cloud/serial-killers/show/91/donald-henry-gaskins'}
# {'name': ' Francisco Guerrero Pérez  El Chalequero, Antonio Prida, The Mexican Barbazul ', 'victims': 21, 'years': 29, 'url': 'https://killer.cloud/serial-killers/show/614/francisco-guerrero-perez'}
# {'name': ' Matti Haapoja   ', 'victims': 3, 'years': 28, 'url': 'https://killer.cloud/serial-killers/show/607/matti-haapoja'}
# {'name': ' Harold Shipman  Dr Death Angel of Death ', 'victims': 15, 'years': 28, 'url': 'https://killer.cloud/serial-killers/show/507/harold-shipman'}
# {'name': ' Nannie Doss  Giggling Nanny, Giggling Granny, Jolly Black Widow ', 'victims': 11, 'years': 28, 'url': 'https://killer.cloud/serial-killers/show/106/nannie-doss'}
# {'name': ' Ali Asghar Borujerdi  Asghar the Murderer, Ashare Qatel ', 'victims': 33, 'years': 28, 'url': 'https://killer.cloud/serial-killers/show/17/ali-asghar-borujerdi'}
# {'name': ' Kenneth McDuff  The Broomstick Killer ', 'victims': 9, 'years': 27, 'url': 'https://killer.cloud/serial-killers/show/147/kenneth-mcduff'}
# {'name': ' Robert Browne  Robert Charles Browne ', 'victims': 2, 'years': 26, 'url': 'https://killer.cloud/serial-killers/show/458/robert-browne'}
# {'name': ' Altemio Sanchez  Bike Path Rapist, Bike Path Killer ', 'victims': 3, 'years': 26, 'url': 'https://killer.cloud/serial-killers/show/402/altemio-sanchez'}
# {'name': ' Richard Biegenwald  The Thrill Killer ', 'victims': 9, 'years': 26, 'url': 'https://killer.cloud/serial-killers/show/149/richard-biegenwald'}
# {'name': ' Terry Rasmussen  The Chameleon Killer, Bear Brook murders, Allenstown Barrel Murders ', 'victims': 5, 'years': 25, 'url': 'https://killer.cloud/serial-killers/show/666/terry-pender-rasmussen'}
# {'name': ' Hamdi Kayapinar  Avcı, insan avcısı ', 'victims': 8, 'years': 25, 'url': 'https://killer.cloud/serial-killers/show/636/hamdi-kayapinar'}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import json
import os
from pathlib import Path

def analyse(killers):
    print("There are",len(killers),"killers returned")
    
    
    
    with open("mafia.csv", "w", encoding="utf-8") as mafia:
        mafia.write("name,victims,years,url\n")

        for x in killers:
            line = f'{x["name"].replace(","," ")},{int(x["victims"])},{int(x["years"])},{x["url"]}\n'
            mafia.write(line)
    boss = pd.read_csv("mafia.csv", sep = ",")
    print(boss.head(10))
    print(boss.describe())
    

killers =  [{'name': ' John Floyd Thomas  Westside Rapist, The Southland Strangler ', 'victims': 5, 'years': 53, 'url': 'https://killer.cloud/serial-killers/show/255/john-floyd-thomas'}, {'name': ' David Parker Ray  The Toy-Box Killer ', 'victims': 3, 'years': 43, 'url': 'https://killer.cloud/serial-killers/show/663/david-parker-ray'}, {'name': ' Richard Kuklinski  The Iceman, The Polack ', 'victims': 6, 'years': 38, 'url': 'https://killer.cloud/serial-killers/show/659/richard-kuklinski'}, {'name': ' Pedro Rodrigues Filho  Pedrinho Matador, Killer Petey ', 'victims': 71, 'years': 37, 'url': 'https://killer.cloud/serial-killers/show/3/pedro-rodrigues-filho'}, {'name': ' Samuel Little  Samuel McDowell ', 'victims': 60, 'years': 36, 'url': 'https://killer.cloud/serial-killers/show/597/sam-little'}, {'name': ' Peter Woodcock  David Michael Krueger ', 'victims': 4, 'years': 36, 'url': 'https://killer.cloud/serial-killers/show/325/peter-woodcock'}, {'name': ' Pedro Lopez  The Monster of the Andes ', 'victims': 110, 'years': 34, 'url': 'https://killer.cloud/serial-killers/show/1/pedro-lopez'}, {'name': ' Volker Eckert  Brummi Killer ', 'victims': 9, 'years': 33, 'url': 'https://killer.cloud/serial-killers/show/141/volker-eckert'}, {'name': ' Carroll Edward Cole  Carroll Cole ', 'victims': 16, 'years': 33, 'url': 'https://killer.cloud/serial-killers/show/60/carroll-cole'}, {'name': ' Louise Peete  Lofie Louise Preslar ', 'victims': 3, 'years': 31, 'url': 'https://killer.cloud/serial-killers/show/385/louise-peete'}, {'name': ' Willem van Eijk  The Beast of Harkstede, Gekke Willempje ', 'victims': 5, 'years': 31, 'url': 'https://killer.cloud/serial-killers/show/299/willem-van-eijk'}, {'name': ' Dennis Rader  BTK Killer, BTK Strangler, Bind Torture Kill ', 'victims': 10, 'years': 31, 'url': 'https://killer.cloud/serial-killers/show/130/dennis-rader'}, {'name': ' David Edward Maust  Crazy Dave ', 'victims': 5, 'years': 30, 'url': 'https://killer.cloud/serial-killers/show/261/david-maust'}, {'name': ' Donald Henry Gaskins  Pee Wee, The Meanest Man in America ', 'victims': 12, 'years': 30, 'url': 'https://killer.cloud/serial-killers/show/91/donald-henry-gaskins'}, {'name': ' Francisco Guerrero Pérez  El Chalequero, Antonio Prida, The Mexican Barbazul ', 'victims': 21, 'years': 29, 'url': 'https://killer.cloud/serial-killers/show/614/francisco-guerrero-perez'}, {'name': ' Matti Haapoja   ', 'victims': 3, 'years': 28, 'url': 'https://killer.cloud/serial-killers/show/607/matti-haapoja'}, {'name': ' Harold Shipman  Dr Death Angel of Death ', 'victims': 15, 'years': 28, 'url': 'https://killer.cloud/serial-killers/show/507/harold-shipman'}, {'name': ' Nannie Doss  Giggling Nanny, Giggling Granny, Jolly Black Widow ', 'victims': 11, 'years': 28, 'url': 'https://killer.cloud/serial-killers/show/106/nannie-doss'}, {'name': ' Ali Asghar Borujerdi  Asghar the Murderer, Ashare Qatel ', 'victims': 33, 'years': 28, 'url': 'https://killer.cloud/serial-killers/show/17/ali-asghar-borujerdi'}, {'name': ' Kenneth McDuff  The Broomstick Killer ', 'victims': 9, 'years': 27, 'url': 'https://killer.cloud/serial-killers/show/147/kenneth-mcduff'}, {'name': ' Robert Browne  Robert Charles Browne ', 'victims': 2, 'years': 26, 'url': 'https://killer.cloud/serial-killers/show/458/robert-browne'}, {'name': ' Altemio Sanchez  Bike Path Rapist, Bike Path Killer ', 'victims': 3, 'years': 26, 'url': 'https://killer.cloud/serial-killers/show/402/altemio-sanchez'}, {'name': ' Richard Biegenwald  The Thrill Killer ', 'victims': 9, 'years': 26, 'url': 'https://killer.cloud/serial-killers/show/149/richard-biegenwald'}, {'name': ' Terry Rasmussen  The Chameleon Killer, Bear Brook murders, Allenstown Barrel Murders ', 'victims': 5, 'years': 25, 'url': 'https://killer.cloud/serial-killers/show/666/terry-pender-rasmussen'}, {'name': ' Hamdi Kayapinar  Avcı, insan avcısı ', 'victims': 8, 'years': 25, 'url': 'https://killer.cloud/serial-killers/show/636/hamdi-kayapinar'}]
analyse(killers)
# Out:
# There are 25 killers returned
#                                                 name  victims  years  \
# 0   John Floyd Thomas  Westside Rapist  The South...        5     53
# 1              David Parker Ray  The Toy-Box Killer         3     43
# 2         Richard Kuklinski  The Iceman  The Polack         6     38
# 3   Pedro Rodrigues Filho  Pedrinho Matador  Kill...       71     37
# 4                    Samuel Little  Samuel McDowell        60     36
# 5             Peter Woodcock  David Michael Krueger         4     36
# 6             Pedro Lopez  The Monster of the Andes       110     34
# 7                      Volker Eckert  Brummi Killer         9     33
# 8                 Carroll Edward Cole  Carroll Cole        16     33
# 9                Louise Peete  Lofie Louise Preslar         3     31
#
#                                                  url
# 0  https://killer.cloud/serial-killers/show/255/j...
# 1  https://killer.cloud/serial-killers/show/663/d...
# 2  https://killer.cloud/serial-killers/show/659/r...
# 3  https://killer.cloud/serial-killers/show/3/ped...
# 4  https://killer.cloud/serial-killers/show/597/s...
# 5  https://killer.cloud/serial-killers/show/325/p...
# 6  https://killer.cloud/serial-killers/show/1/ped...
# 7  https://killer.cloud/serial-killers/show/141/v...
# 8  https://killer.cloud/serial-killers/show/60/ca...
# 9  https://killer.cloud/serial-killers/show/385/l...
#           victims      years
# count   25.000000  25.000000
# mean    17.520000  31.680000
# std     25.773242   6.368673
# min      2.000000  25.000000
# 25%      5.000000  28.000000
# 50%      9.000000  30.000000
# 75%     15.000000  34.000000
# max    110.000000  53.000000

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import json

def top_killers(n, sort_by, location):
    
    if location != "world":
        url = f"https://killer.cloud/serial-killers/by/country/{location.lower()}"
        headers = {'User-Agent' : 'Anthony'}
        response = requests.get(url, headers=headers)
        #print(response.status_code)
        #html = response.text    
        soup = BeautifulSoup(response.content, 'html.parser')

        naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
        victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
        act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
        links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})

        finalList = []
        for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
            diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
            finalList.append(diction)

        p = 2    
        while len(finalList) < n:
            url =  f"https://killer.cloud/serial-killers/by/country/{location}?page={p}"
            p += 1
            headers = {'User-Agent' : 'Anthony'}
            response = requests.get(url, headers=headers)   
            soup = BeautifulSoup(response.content, 'html.parser')

            naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
            victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
            act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
            links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})

            if not naamen:
                break
            for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
                diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
                finalList.append(diction)
   
        if n < len(finalList):
            return finalList[:n]
        else:
            return finalList
        
    elif location == "world": 
        if sort_by == "confirmed-kills":
            url = f"https://killer.cloud/serial-killers/by/{sort_by}?page=1"
            headers = {'User-Agent' : 'Anthony'}
            response = requests.get(url, headers=headers)
            #print(response.status_code)
            #html = response.text    
            soup = BeautifulSoup(response.content, 'html.parser')

            naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
            victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
            act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
            links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})

            finale = []
            for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
                diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
                finale.append(diction)
            p = 2
            #print(finale, "just the list")
            
                
            while len(finale) < n:
                url = f"https://killer.cloud/serial-killers/by/{sort_by}?page={p}"
                p += 1
                headers = {'User-Agent' : 'Anthony'}
                response = requests.get(url, headers=headers)
                #print(response.status_code)
                #html = response.text    
                soup = BeautifulSoup(response.content, 'html.parser')

                naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
                victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
                act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
                links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})

                for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
                    diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
                    finale.append(diction)
    
            if n < len(finale):
                return finale[:n]
            else:
                return finale

        elif sort_by == "years-active":

            url = f"https://killer.cloud/serial-killers/by/{sort_by}"
            headers = {'User-Agent' : 'Anthony'}
            response = requests.get(url, headers=headers)
            #print(response.status_code)
            #html = response.text    
            soup = BeautifulSoup(response.content, 'html.parser')

            naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
            victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
            act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
            links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})


            finale = []
            for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
                diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
                finale.append(diction)
            p = 2

            while len(finale) < n:
                url = f"https://killer.cloud/serial-killers/by/{sort_by}?page={p}"
                p += 1
                headers = {'User-Agent' : 'Anthony'}
                response = requests.get(url, headers=headers)
                #print(response.status_code)
                #html = response.text    
                soup = BeautifulSoup(response.content, 'html.parser')

                naamen = soup.find_all("h3", class_=lambda c: c and "pad10t" in c and "mar5t" in c and "font-hel" in c)
                victims = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad10t" in c and "font-hel" in c)
                act_years = soup.find_all("h4", class_=lambda c: c and "mar0" in c and "pad15tb" in c and "font-hel" in c)
                links = soup.find_all("a", {'class' : 'bl text-left mar5tb'})

                for i in range(min(len(naamen), len(victims), len(act_years), len(links))):
                    diction = {'name' : naamen[i].get_text(),'victims': int(victims[i].get_text()),'years' : int(act_years[i].get_text()),'url' :  links[i]['href']}
                    finale.append(diction)
   
            if n < len(finale):
                return finale[:n] 
            else:
                return finale

def analyse(killers):
    return killers
                

def main():
    print("Hello")



    
if __name__ == "__main__":
     print("Enter a country (or 'world'): Sort by (confirmed-kills / years-active): How many killers?")
# Out:
# Enter a country (or 'world'): Sort by (confirmed-kills / years-active): How many killers?

# %%
#%pip install pandas
