# %%
def read_matrix():
    Matrix = []
    
    row1 = map(int, input("Please input your matrix below:").split())
    rows1 = list(row1)
    print(rows1)
    
    Matrix.append(rows1)
    
    
    row2 = map(int, input().split())
    rows2 = list(row2)
    print(rows2)
    
    Matrix.append(rows2)
    print(Matrix)
 
print("Your matrix:")   
read_matrix()
# Out:
# Your matrix:
# [1, 2, 3]
# [4, 5, 6]
# [[1, 2, 3], [4, 5, 6]]

# %%
def read_matrix():
    Matrix = []
    
    row = map(int, input("Please input your matrix below:\n").split())
    row_list = list(row)

    while len(row_list) != 0:
            
        for i in row_list:
           print(i, end = " ")     
        Matrix.append(row_list)
        print()
            
        row = map(int, input().split())
        row_list = list(row)
       

    print("Your matrix:") 
    print(Matrix)

   
    tempMat = [x for x in Matrix]
    
    
    def scalar_multiplication(matrix,scalar):
        
        for i in range(0,len(matrix)):
            for j in range(0,len(matrix[i])):
                matrix[i][j] = matrix[i][j] * scalar 

        print("Scalar multiplication with 8:")      
        print(matrix)
    scalar_multiplication(tempMat,8)

    def transpose(matrix):
        r = len(matrix)
        c = len(matrix[0])
      

        transMat = []
        for j in range(c):
           ROW = []
           for i in range(r):
                matrix[i][j] = matrix[i][j] // 8
                ROW.append(matrix[i][j])
           transMat.append(ROW)
        
        print("Transposition:")
        print(transMat)
       
        
    transpose(Matrix)


read_matrix()
# Out:
# 1 5 6
# 1 2 4
# Your matrix:
# [[1, 5, 6], [1, 2, 4]]
# Scalar multiplication with 8:
# [[8, 40, 48], [8, 16, 32]]
# Transposition:
# [[1, 1], [5, 2], [6, 4]]

# %%
def scalar_multiplication(matrix, scalar):
    for i in matrix:
        print(i*8)
        
mat = read_matrix()       
s = scalar_multiplication(mat,8)
print(s)
# Out:
# [1, 2]
# [5, 6]
# Your matrix:
# [[1, 2], [5, 6]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3         return i
#       5 mat = read_matrix()
# ----> 6 s= scalar_multiplication(mat,8)
#       7 print(s)
#
# Cell In[5], line 2, in scalar_multiplication(matrix, scalar)
#       1 def scalar_multiplication(matrix, scalar):
# ----> 2     for i in matrix:
#       3         return i
#
# TypeError: 'NoneType' object is not iterable

# %%
list = [[1,2,3], [4,5,6]]
print(list)
print(len(list))
# Out:
# [[1, 2, 3], [4, 5, 6]]
# 2

# %%
number_grid = [
     [1,2,3],
     [4,5,6],
     [7,8,9],
     [0]
]

print(number_grid[2][1])


for row in number_grid:
    for col in row:
        print(col, end=" ")
    print()
# Out:
# 8
# 1 2 3
# 4 5 6
# 7 8 9
# 0

# %%
x = int(input("Enter the value for row:"))
y = int(input("Enter the value for col:"))
Mat = [] # for creating a blank matrix

for i in range(0,x):#for creating the inner list
    Mat.append([]) # for adding a list to the matrix
    

for i in range(0,x):#row
    for j in range(0,y): #column
          Mat[i].append(j) # will add the elements
          Mat[i][j] = 0

# %%
def read_matrix():
    
    number = map(int, input("Please type your matrix below:").split())
    numbers = list(number)
    print(numbers)
    x = len(numbers)
    print(x)
    
    matrix = []
    num = map(int, input().split())
    
read_matrix()
# Out:
# [1, 5, 6, 9]
# 4

# %% [markdown]
# ##Ideology for the matrix
# Create a giant list
#
# Input for the first time a series of numbers splitted by a space
# Put them in a list
#
# Add them to the giant list
#
# Input for the second time a series of numbers splitted by a space
# Put them in a list
#
# Add them to the giant list
